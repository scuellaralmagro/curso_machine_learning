# %% [markdown]
# # Condicionales

# %% [markdown]
# En esta sección veremos la sentencia condicional `if` y las distintas variantes que puede asumir, pero antes de eso introduciremos algunas cuestiones generales de escritura de código.

# %% [markdown]
# ### Operadores de comparación

# %% [markdown]
# A continuación se muestra la tabla de los operadores de comparación en Python:

# %% [markdown]
# Operador | Símbolo
# --- | ---
# Igualdad | `==`
# Desigualdad | `!=`
# Menor que | `<`
# Menor o igual que | `<=`
# Mayor que | `>`
# Mayor o igual que | `>=`

# %% [markdown]
# Estos operadores devuelven valores booleanos `True` o `False`. Veamos un ejemplo:

# %%
x = 7
x == 5
# Out:
# False

# %%
x == 7
# Out:
# True

# %%
5 < x
# Out:
# True

# %%
x < 10
# Out:
# True

# %% [markdown]
# Podemos escribir condiciones más complejas usando los operadores lógicos `and`, `or` y `not`:

# %%
(5 < x) or (x > 10)    # se recomienda el uso de paréntesis
# Out:
# True

# %%
(5 < x) and (not (x > 10))
# Out:
# True

# %%
(5 < x) and (x < 10)
# Out:
# True

# %% [markdown]
# Esta última comparación también se pueden escribir en Python de la siguiente forma:

# %%
5 < x < 10
# Out:
# True

# %% [markdown]
# ## ¿Qué es cierto?
#
# Python considera `False` a todo lo que está en la siguiente tabla:

# %% [markdown]
# Elemento | Representación
# --- | ---
# Booleano | `False`
# Nulo | `None`
# Cero entero | `0`
# Cero flotante | `0.0`
# Cadena vacía | `''`
# Tupla vacía | `()`
# Diccionario vacío | `{}`
# Conjunto vacío | `set()`

# %% [markdown]
# ✅ Cualquier otra cosa se considera `True`

# %% [markdown]
# Ejemplo de verificación de lista vacía:

# %%
lista = []

if lista:
    print('Hay algo en la lista')
else:
    print('La lista está vacía')
# Out:
# La lista está vacía

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Simula el siguiente diagrama de flujo de personajes Marvel utilizando sentencias condicionales:
#
# ![marvel-flowchart.png](data:image/png;base64,...)

# %%
# Escriba aquí su solución
#Si introducimos:
can_fly = int(input('¿Puede volar? 0 si no, 1 si sí: '))
is_human = int(input('¿Es Humano? 0 si no, 1 si sí: '))
has_mask = int(input('¿Tiene máscara? 0 si no, 1 si sí: '))
#Debe devolver: "Vision"

if can_fly == True:
    if is_human == True:
        if has_mask == True:
            print('Ironman')
        else:
            print('Captain Marvel')
    else:
        if has_mask == True:
            print('Ronan Accuser')
        else:
            print('Vision') 
else:
    if is_human == True:
        if has_mask == True:
            print('Spiderman')
        else:
            print('Hulk')
    else:
        if has_mask == True:
            print('Black Bolt')
        else:
            print('Thanos')
# Out:
# Thanos
# 0
# 0
# 0

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Dada una variable `year` con un valor entero, comprueba si dicho año es bisiesto o no.
#
# *   Pista: Un año es bisiesto en el calendario Gregoriano, si es divisible entre 4 y no divisible entre 100. O si es divisible entre 400.
#
# *    Puedes hacer la comprobación en [esta lista de años bisiestos](https://kalender-365.de/leap-years.php).

# %%
# Escriba aquí su solución
anyo = 2000

if (anyo % 4 == 0 and anyo % 100 != 0) or anyo % 400 == 0:
    print('El año es bisiesto.')
else:
    print('El año no es bisiesto.')
# Out:
# El año es bisiesto.

# %% [markdown]
# ### Ejercicio 3
#
# Determina si una cadena de texto dada es un [palíndromo](https://es.wikipedia.org/wiki/Pal%C3%ADndromo).

# %%
#Input:
sentence = 'Dabale arroz a la zorra el abad'
# Escriba aquí su solución
sentence_no_space = "".join(sentence.split()).lower()   # Quita espacios y mayúsculas.

if sentence_no_space[::-1] == sentence_no_space:
    print('Es palíndromo')
else:
    print('No es palíndromo')
# Out:
# Es palíndromo
